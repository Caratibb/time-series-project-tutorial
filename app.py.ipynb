# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.arima.model import ARIMA
from prophet import Prophet
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 6
#       4 import seaborn as sns
#       5 from statsmodels.tsa.arima.model import ARIMA
# ----> 6 from prophet import Prophet
#       7 from sklearn.model_selection import train_test_split
#       8 from sklearn.metrics import mean_squared_error
#
# ModuleNotFoundError: No module named 'prophet'

# %%
# Load Datasets
aquifer_auser = pd.read_csv('./data/Aquifer_Auser.csv')
Aquifer_Doganella = pd.read_csv('./data/Aquifer_Doganella.csv')
Aquifer_Luco = pd.read_csv('./data/Aquifer_Luco.csv')
Aquifer_Petrignano = pd.read_csv('./data/Aquifer_Petrignano.csv')
Lake_Bilancino = pd.read_csv('./data/Lake_Bilancino.csv')
River_Arno = pd.read_csv('./data/River_Arno.csv')
Water_Spring_Amiata = pd.read_csv('./data/Water_Spring_Amiata.csv')
Water_Spring_Lupa = pd.read_csv('./data/Water_Spring_Lupa.csv')
Water_Spring_Madonna_di_Canneto = pd.read_csv('./data/Water_Spring_Madonna_di_Canneto.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Load Datasets
# ----> 2 aquifer_auser = pd.read_csv('./data/Aquifer_Auser.csv')
#       3 Aquifer_Doganella = pd.read_csv('./data/Aquifer_Doganella.csv')
#       4 Aquifer_Luco = pd.read_csv('./data/Aquifer_Luco.csv')
#
# ...

# %%
# Data Cleaning & Preprocessing
# Inspect data for missing values and datatypes
print(aquifer_auser.info())
print(aquifer_auser.isnull().sum()) 
print(aquifer_doganella.info())
print(aquifer_doganella.isnull().sum()) 
print(Aquifer_Luco.info())
print(Aquifer_Luco.isnull().sum()) 
print(Aquifer_Petrignano.info())
print(Aquifer_Petrignano.isnull().sum()) 
print(Lake_Bilancino.info())
print(Lake_Bilancino.isnull().sum()) 
print(River_Arno.info())
print(River_Arno.isnull().sum()) 
print(Water_Spring_Amiata.info())
print(Water_Spring_Amiata.isnull().sum()) 
print(Water_Spring_Lupa.info())
print(Water_Spring_Lupa.isnull().sum()) 
print(Water_Spring_Madonna_di_Canneto.info())
print(Water_Spring_Madonna_di_Canneto.isnull().sum())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 # Data Cleaning & Preprocessing
#       2 # Inspect data for missing values and datatypes
# ----> 3 print(aquifer_auser.info())
#       4 print(aquifer_auser.isnull().sum())
#       5 print(aquifer_doganella.info())
#
# NameError: name 'aquifer_auser' is not defined

# %%
# Handling missing values
aquifer_auser['Water Volume'] = aquifer_auser['Water Volume'].interpolate(method='linear')
aquifer_doganella['Water Volume'] = aquifer_doganella['Water Volume'].interpolate(method='linear')
Aquifer_Luco['Water Volume'] = Aquifer_Luco['Water Volume'].interpolate(method='linear')
Aquifer_Petrignano['Water Volume'] = Aquifer_Petrignano['Water Volume'].interpolate(method='linear')
Lake_Bilancino['Water Volume'] = Lake_Bilancino['Water Volume'].interpolate(method='linear')
River_Arno['Water Volume'] = River_Arno['Water Volume'].interpolate(method='linear')
Water_Spring_Amiata['Water Volume'] = Water_Spring_Amiata['Water Volume'].interpolate(method='linear')
Water_Spring_Lupa['Water Volume'] = Water_Spring_Lupa['Water Volume'].interpolate(method='linear')
Water_Spring_Madonna_di_Canneto['Water Volume'] = Water_Spring_Madonna_di_Canneto['Water Volume'].interpolate(method='linear')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Handling missing values
# ----> 2 aquifer_auser['Water Volume'] = aquifer_auser['Water Volume'].interpolate(method='linear')
#       3 aquifer_doganella['Water Volume'] = aquifer_doganella['Water Volume'].interpolate(method='linear')
#       4 Aquifer_Luco['Water Volume'] = Aquifer_Luco['Water Volume'].interpolate(method='linear')
#
# NameError: name 'aquifer_auser' is not defined

# %%
# Convert date columns to datetime format (if applicable)
aquifer_auser['Date'] = pd.to_datetime(aquifer_auser['Date'])
Aquifer_Doganella['Date'] = pd.to_datetime(Aquifer_Doganella['Date'])
Aquifer_Luco['Date'] = pd.to_datetime(Aquifer_Luco['Date'])
Aquifer_Petrignano['Date'] = pd.to_datetime(Aquifer_Petrignano['Date'])
Lake_Bilancino['Date'] = pd.to_datetime(Lake_Bilancino['Date'])
River_Arno ['Date'] = pd.to_datetime(River_Arno['Date'])
Water_Spring_Amiata ['Date'] = pd.to_datetime(Water_Spring_Amiata ['Date'])
Water_Spring_Lupa ['Date'] = pd.to_datetime(Water_Spring_Lupa ['Date'])
Water_Spring_Madonna_di_Canneto ['Date'] = pd.to_datetime(Water_Spring_Madonna_di_Canneto ['Date'])

# %%
# Resample or aggregate to monthly intervals 
aquifer_auser.set_index('Date', inplace=True)
aquifer_auser_monthly = aquifer_auser.resample('M').mean()
Aquifer_Doganella.set_index('Date', inplace=True)
Aquifer_Doganella_monthly = Aquifer_Doganella.resample('M').mean()
Aquifer_Luco.set_index('Date', inplace=True)
Aquifer_Luco_monthly = Aquifer_Luco.resample('M').mean()
Aquifer_Petrignano.set_index('Date', inplace=True)
Aquifer_Petrignano_monthly = Aquifer_Petrignano.resample('M').mean()
Lake_Bilancino.set_index('Date', inplace=True)
Lake_Bilancino_monthly = Lake_Bilancino.resample('M').mean()
River_Arno.set_index('Date', inplace=True)
River_Arno_monthly = River_Arno.resample('M').mean()
Water_Spring_Amiata.set_index('Date', inplace=True)
Water_Spring_Amiata_monthly = Water_Spring_Amiata.resample('M').mean()
Water_Spring_Lupa.set_index('Date', inplace=True)
Water_Spring_Lupa_monthly = Water_Spring_Lupa.resample('M').mean()
Water_Spring_Madonna_di_Canneto.set_index('Date', inplace=True)
Water_Spring_Madonna_di_Canneto_monthly = Water_Spring_Madonna_di_Canneto.resample('M').mean()

# %%
# 6. Handling outliers using IQR method
Q1 = aquifer_auser['Water Volume'].quantile(0.25)
Q3 = aquifer_auser['Water Volume'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
Q1 = Aquifer_Doganella['Water Volume'].quantile(0.25)
Q3 = Aquifer_Doganella['Water Volume'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
Q1 = Aquifer_Luco['Water Volume'].quantile(0.25)
Q3 = Aquifer_Luco['Water Volume'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
Q1 = Aquifer_Petrignano['Water Volume'].quantile(0.25)
Q3 = Aquifer_Petrignano['Water Volume'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
Q1 = Lake_Bilancino['Water Volume'].quantile(0.25)
Q3 = Lake_Bilancino['Water Volume'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
Q1 = River_Arno['Water Volume'].quantile(0.25)
Q3 = River_Arno['Water Volume'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
Q1 = Water_Spring_Amiata['Water Volume'].quantile(0.25)
Q3 = Water_Spring_Amiata['Water Volume'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
Q1 = Water_Spring_Lupa['Water Volume'].quantile(0.25)
Q3 = Water_Spring_Lupa['Water Volume'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
Q1 = aquifer_auser['Water Volume'].quantile(0.25)
Q3 = aquifer_auser['Water Volume'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
Q1 = Water_Spring_Madonna_di_Canneto['Water Volume'].quantile(0.25)
Q3 = Water_Spring_Madonna_di_Canneto['Water Volume'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
# Capping the outliers
aquifer_auser['Water Volume'] = aquifer_auser['Water Volume'].apply(lambda x: upper_bound if x > upper_bound else (lower_bound if x < lower_bound else x))
Aquifer_Doganella ['Water Volume'] = Aquifer_Doganella ['Water Volume'].apply(lambda x: upper_bound if x > upper_bound else (lower_bound if x < lower_bound else x))
Aquifer_Luco['Water Volume'] = Aquifer_Luco['Water Volume'].apply(lambda x: upper_bound if x > upper_bound else (lower_bound if x < lower_bound else x))
Aquifer_Petrignano['Water Volume'] = Aquifer_Petrignano['Water Volume'].apply(lambda x: upper_bound if x > upper_bound else (lower_bound if x < lower_bound else x))
Lake_Bilancino['Water Volume'] = Lake_Bilancino['Water Volume'].apply(lambda x: upper_bound if x > upper_bound else (lower_bound if x < lower_bound else x))
River_Arno['Water Volume'] = River_Arno['Water Volume'].apply(lambda x: upper_bound if x > upper_bound else (lower_bound if x < lower_bound else x))
Water_Spring_Amiata['Water Volume'] = Water_Spring_Amiata['Water Volume'].apply(lambda x: upper_bound if x > upper_bound else (lower_bound if x < lower_bound else x))
Water_Spring_Lupa['Water Volume'] = Water_Spring_Lupa['Water Volume'].apply(lambda x: upper_bound if x > upper_bound else (lower_bound if x < lower_bound else x))
Water_Spring_Madonna_di_Canneto['Water Volume'] = Water_Spring_Madonna_di_Canneto['Water Volume'].apply(lambda x: upper_bound if x > upper_bound else (lower_bound if x < lower_bound else x))

# %%
#  Feature Engineering
aquifer_auser['Year'] = aquifer_auser.index.year
aquifer_auser['Month'] = aquifer_auser.index.month
aquifer_auser['Rolling_7'] = aquifer_auser['Water Volume'].rolling(window=7).mean()
Aquifer_Doganella['Year'] = Aquifer_Doganella.index.year
Aquifer_Doganella['Month'] = Aquifer_Doganella.index.month
Aquifer_Doganella['Rolling_7'] = Aquifer_Doganella['Water Volume'].rolling(window=7).mean()
Aquifer_Luco['Year'] = Aquifer_Luco.index.year
Aquifer_Luco['Month'] = Aquifer_Luco.index.month
Aquifer_Luco['Rolling_7'] = Aquifer_Luco['Water Volume'].rolling(window=7).mean()
Aquifer_Petrignano['Year'] = Aquifer_Petrignano.index.year
Aquifer_Petrignano['Month'] = Aquifer_Petrignano.index.month
Aquifer_Petrignano['Rolling_7'] = Aquifer_Petrignano['Water Volume'].rolling(window=7).mean()
Lake_Bilancino['Year'] = Lake_Bilancino.index.year
Lake_Bilancino['Month'] = Lake_Bilancino.index.month
Lake_Bilancino['Rolling_7'] = Lake_Bilancino['Water Volume'].rolling(window=7).mean()
River_Arno['Year'] = River_Arno.index.year
River_Arno['Month'] = River_Arno.index.month
River_Arno['Rolling_7'] = River_Arno['Water Volume'].rolling(window=7).mean()
Water_Spring_Amiata['Year'] = Water_Spring_Amiata.index.year
Water_Spring_Amiata['Month'] = Water_Spring_Amiata.index.month
Water_Spring_Amiata['Rolling_7'] = Water_Spring_Amiata['Water Volume'].rolling(window=7).mean()
Water_Spring_Lupa['Year'] = Water_Spring_Lupa.index.year
Water_Spring_Lupa['Month'] =Water_Spring_Lupa.index.month
Water_Spring_Lupa['Rolling_7'] = Water_Spring_Lupa['Water Volume'].rolling(window=7).mean()
Water_Spring_Madonna_di_Canneto['Year'] = Water_Spring_Madonna_di_Canneto.index.year
Water_Spring_Madonna_di_Canneto['Month'] = Water_Spring_Madonna_di_Canneto.index.month
Water_Spring_Madonna_di_Canneto['Rolling_7'] = Water_Spring_Madonna_di_Canneto['Water Volume'].rolling(window=7).mean()

# %%
# Normalization/Standardization (optional based on model requirements)
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
aquifer_auser_scaled = scaler.fit_transform(aquifer_auser[['Water Volume', 'Rolling_7']])
Aquifer_Doganella_scaled = scaler.fit_transform(Aquifer_Doganella[['Water Volume', 'Rolling_7']])
Aquifer_Luco_scaled = scaler.fit_transform(Aquifer_Luco[['Water Volume', 'Rolling_7']])
Aquifer_Petrignano_scaled = scaler.fit_transform(Aquifer_Petrignano[['Water Volume', 'Rolling_7']])
Lake_Bilancino_scaled = scaler.fit_transform(Lake_Bilancino[['Water Volume', 'Rolling_7']])
River_Arno_scaled = scaler.fit_transform(River_Arno[['Water Volume', 'Rolling_7']])
Water_Spring_Amiata_scaled = scaler.fit_transform(Water_Spring_Amiata[['Water Volume', 'Rolling_7']])
Water_Spring_Lupa_scaled = scaler.fit_transform(Water_Spring_Lupa[['Water Volume', 'Rolling_7']])
Water_Spring_Madonna_di_Canneto_scaled = scaler.fit_transform(Water_Spring_Madonna_di_Canneto[['Water Volume', 'Rolling_7']])

# %%
# 9. Split the dataset into training and test sets
train_size = int(len(aquifer_auser) * 0.8)
train = aquifer_auser[:train_size]
test = aquifer_auser[train_size:]
train_size = int(len(Aquifer_Doganella ) * 0.8)
train = Aquifer_Doganella [:train_size]
test = Aquifer_Doganella [train_size:]
train_size = int(len(Aquifer_Luco) * 0.8)
train = Aquifer_Luco[:train_size]
test = Aquifer_Luco[train_size:]
train_size = int(len(Aquifer_Petrignano) * 0.8)
train =Aquifer_Petrignano[:train_size]
test = Aquifer_Petrignano[train_size:]
train_size = int(len(Lake_Bilancino) * 0.8)
train = Lake_Bilancino[:train_size]
test = Lake_Bilancino[train_size:]
train_size = int(len(River_Arno) * 0.8)
train = River_Arno[:train_size]
test = River_Arno[train_size:]
train_size = int(len(Water_Spring_Amiata) * 0.8)
train = Water_Spring_Amiata[:train_size]
test = Water_Spring_Amiata[train_size:]
train_size = int(len(Water_Spring_Lupa) * 0.8)
train = Water_Spring_Lupa[:train_size]
test = Water_Spring_Lupa[train_size:]
train_size = int(len(Water_Spring_Madonna_di_Canneto) * 0.8)
train = Water_Spring_Madonna_di_Canneto[:train_size]
test = Water_Spring_Madonna_di_Canneto[train_size:]

# %%
# Visualize Water Volume over Time
plt.figure(figsize=(10, 6))
plt.plot(aquifer_auser['Date'], aquifer_auser['Water Volume'], label='Water Volume')
plt.title('Water Volume Over Time (Aquifer Auser)')
plt.xlabel('Date')
plt.ylabel('Water Volume')
plt.legend()
plt.show()
plt.figure(figsize=(10, 6))
plt.plot(Aquifer_Doganella['Date'], Aquifer_Doganella['Water Volume'], label='Water Volume')
plt.title('Water Volume Over Time (Aquifer Auser)')
plt.xlabel('Date')
plt.ylabel('Water Volume')
plt.legend()
plt.show()
plt.figure(figsize=(10, 6))
plt.plot(Aquifer_Luco['Date'], Aquifer_Luco['Water Volume'], label='Water Volume')
plt.title('Water Volume Over Time (Aquifer Auser)')
plt.xlabel('Date')
plt.ylabel('Water Volume')
plt.legend()
plt.show()
plt.figure(figsize=(10, 6))
plt.plot(Aquifer_Petrignano['Date'], Aquifer_Petrignano['Water Volume'], label='Water Volume')
plt.title('Water Volume Over Time (Aquifer Auser)')
plt.xlabel('Date')
plt.ylabel('Water Volume')
plt.legend()
plt.show()
plt.figure(figsize=(10, 6))
plt.plot(Lake_Bilancino['Date'], Lake_Bilancino['Water Volume'], label='Water Volume')
plt.title('Water Volume Over Time (Aquifer Auser)')
plt.xlabel('Date')
plt.ylabel('Water Volume')
plt.legend()
plt.show()
plt.figure(figsize=(10, 6))
plt.plot(River_Arno['Date'], River_Arno['Water Volume'], label='Water Volume')
plt.title('Water Volume Over Time (Aquifer Auser)')
plt.xlabel('Date')
plt.ylabel('Water Volume')
plt.legend()
plt.show()
plt.figure(figsize=(10, 6))
plt.plot(Water_Spring_Amiata['Date'], Water_Spring_Amiata['Water Volume'], label='Water Volume')
plt.title('Water Volume Over Time (Aquifer Auser)')
plt.xlabel('Date')
plt.ylabel('Water Volume')
plt.legend()
plt.show()
plt.figure(figsize=(10, 6))
plt.plot(Water_Spring_Lupa['Date'], Water_Spring_Lupa['Water Volume'], label='Water Volume')
plt.title('Water Volume Over Time (Aquifer Auser)')
plt.xlabel('Date')
plt.ylabel('Water Volume')
plt.legend()
plt.show()
plt.figure(figsize=(10, 6))
plt.plot(Water_Spring_Madonna_di_Canneto['Date'], Water_Spring_Madonna_di_Canneto['Water Volume'], label='Water Volume')
plt.title('Water Volume Over Time (Aquifer Auser)')
plt.xlabel('Date')
plt.ylabel('Water Volume')
plt.legend()
plt.show()

# %%
# 2. Distribution of Water Volume
plt.figure(figsize=(8, 5))
sns.histplot(aquifer_auser['Water Volume'], kde=True)
plt.title('Distribution of Water Volume')
plt.xlabel('Water Volume')
plt.show()
plt.figure(figsize=(8, 5))
sns.histplot(Aquifer_Doganella['Water Volume'], kde=True)
plt.title('Distribution of Water Volume')
plt.xlabel('Water Volume')
plt.show()
plt.figure(figsize=(8, 5))
sns.histplot(Aquifer_Luco['Water Volume'], kde=True)
plt.title('Distribution of Water Volume')
plt.xlabel('Water Volume')
plt.show()
plt.figure(figsize=(8, 5))
sns.histplot(Aquifer_Petrignano['Water Volume'], kde=True)
plt.title('Distribution of Water Volume')
plt.xlabel('Water Volume')
plt.show()
plt.figure(figsize=(8, 5))
sns.histplot(Lake_Bilancino['Water Volume'], kde=True)
plt.title('Distribution of Water Volume')
plt.xlabel('Water Volume')
plt.show()
plt.figure(figsize=(8, 5))
sns.histplot(River_Arno['Water Volume'], kde=True)
plt.title('Distribution of Water Volume')
plt.xlabel('Water Volume')
plt.show()
plt.figure(figsize=(8, 5))
sns.histplot(Water_Spring_Amiata['Water Volume'], kde=True)
plt.title('Distribution of Water Volume')
plt.xlabel('Water Volume')
plt.show()
plt.figure(figsize=(8, 5))
sns.histplot(Water_Spring_Lupa['Water Volume'], kde=True)
plt.title('Distribution of Water Volume')
plt.xlabel('Water Volume')
plt.show()
plt.figure(figsize=(8, 5))
sns.histplot(Water_Spring_Madonna_di_Canneto['Water Volume'], kde=True)
plt.title('Distribution of Water Volume')
plt.xlabel('Water Volume')
plt.show()

# %%
# 3. Correlation Heatmap
# Assuming we have other numerical features in the dataset (e.g., rainfall, temperature)
plt.figure(figsize=(10, 6))
correlation_matrix = aquifer_auser.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Feature Correlation Heatmap')
plt.show()
plt.figure(figsize=(10, 6))
correlation_matrix = Aquifer_Doganella.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Feature Correlation Heatmap')
plt.show()
plt.figure(figsize=(10, 6))
correlation_matrix = Aquifer_Luco.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Feature Correlation Heatmap')
plt.show()
plt.figure(figsize=(10, 6))
correlation_matrix = Aquifer_Petrignano.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Feature Correlation Heatmap')
plt.show()
plt.figure(figsize=(10, 6))
correlation_matrix = Lake_Bilancino.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Feature Correlation Heatmap')
plt.show()
plt.figure(figsize=(10, 6))
correlation_matrix = River_Arno.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Feature Correlation Heatmap')
plt.show()
plt.figure(figsize=(10, 6))
correlation_matrix = Water_Spring_Amiata.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Feature Correlation Heatmap')
plt.show()
plt.figure(figsize=(10, 6))
correlation_matrix = Water_Spring_Lupa.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Feature Correlation Heatmap')
plt.show()
plt.figure(figsize=(10, 6))
correlation_matrix = Water_Spring_Madonna_di_Canneto.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Feature Correlation Heatmap')
plt.show()

# %%
# 4. Seasonal Trends (Water Volume by Month)
aquifer_auser['Month'] = aquifer_auser['Date'].dt.month
monthly_avg = aquifer_auser.groupby('Month')['Water Volume'].mean()
plt.figure(figsize=(8, 5))
sns.barplot(x=monthly_avg.index, y=monthly_avg.values)
plt.title('Average Water Volume by Month')
plt.xlabel('Month')
plt.ylabel('Average Water Volume')
plt.show()
Aquifer_Doganella['Month'] = Aquifer_Doganella['Date'].dt.month
monthly_avg = Aquifer_Doganella.groupby('Month')['Water Volume'].mean()
plt.figure(figsize=(8, 5))
sns.barplot(x=monthly_avg.index, y=monthly_avg.values)
plt.title('Average Water Volume by Month')
plt.xlabel('Month')
plt.ylabel('Average Water Volume')
plt.show()
Aquifer_Luco['Month'] = Aquifer_Luco['Date'].dt.month
monthly_avg = Aquifer_Luco.groupby('Month')['Water Volume'].mean()
plt.figure(figsize=(8, 5))
sns.barplot(x=monthly_avg.index, y=monthly_avg.values)
plt.title('Average Water Volume by Month')
plt.xlabel('Month')
plt.ylabel('Average Water Volume')
plt.show()
Aquifer_Petrignano['Month'] = Aquifer_Petrignano['Date'].dt.month
monthly_avg = Aquifer_Petrignano.groupby('Month')['Water Volume'].mean()
plt.figure(figsize=(8, 5))
sns.barplot(x=monthly_avg.index, y=monthly_avg.values)
plt.title('Average Water Volume by Month')
plt.xlabel('Month')
plt.ylabel('Average Water Volume')
plt.show()
Lake_Bilancino['Month'] = Lake_Bilancino['Date'].dt.month
monthly_avg = Lake_Bilancino.groupby('Month')['Water Volume'].mean()
plt.figure(figsize=(8, 5))
sns.barplot(x=monthly_avg.index, y=monthly_avg.values)
plt.title('Average Water Volume by Month')
plt.xlabel('Month')
plt.ylabel('Average Water Volume')
plt.show()
River_Arno['Month'] = River_Arno['Date'].dt.month
monthly_avg = River_Arno.groupby('Month')['Water Volume'].mean()
plt.figure(figsize=(8, 5))
sns.barplot(x=monthly_avg.index, y=monthly_avg.values)
plt.title('Average Water Volume by Month')
plt.xlabel('Month')
plt.ylabel('Average Water Volume')
plt.show()
Water_Spring_Amiata['Month'] = Water_Spring_Amiata['Date'].dt.month
monthly_avg = Water_Spring_Amiata.groupby('Month')['Water Volume'].mean()
plt.figure(figsize=(8, 5))
sns.barplot(x=monthly_avg.index, y=monthly_avg.values)
plt.title('Average Water Volume by Month')
plt.xlabel('Month')
plt.ylabel('Average Water Volume')
plt.show()
Water_Spring_Lupa['Month'] = Water_Spring_Lupa['Date'].dt.month
monthly_avg = Water_Spring_Lupa.groupby('Month')['Water Volume'].mean()
plt.figure(figsize=(8, 5))
sns.barplot(x=monthly_avg.index, y=monthly_avg.values)
plt.title('Average Water Volume by Month')
plt.xlabel('Month')
plt.ylabel('Average Water Volume')
plt.show()
Water_Spring_Madonna_di_Canneto['Month'] = Water_Spring_Madonna_di_Canneto['Date'].dt.month
monthly_avg = Water_Spring_Madonna_di_Canneto.groupby('Month')['Water Volume'].mean()
plt.figure(figsize=(8, 5))
sns.barplot(x=monthly_avg.index, y=monthly_avg.values)
plt.title('Average Water Volume by Month')
plt.xlabel('Month')
plt.ylabel('Average Water Volume')
plt.show()

# %%
# Pair Plots for Feature Relationships
sns.pairplot(aquifer_auser[['Water Volume', 'Temperature', 'Rainfall']])
plt.show()
sns.pairplot(Aquifer_Doganella[['Water Volume', 'Temperature', 'Rainfall']])
plt.show()
sns.pairplot(Aquifer_Luco[['Water Volume', 'Temperature', 'Rainfall']])
plt.show()
sns.pairplot(Aquifer_Petrignano[['Water Volume', 'Temperature', 'Rainfall']])
plt.show()
sns.pairplot(Lake_Bilancino[['Water Volume', 'Temperature', 'Rainfall']])
plt.show()
sns.pairplot(River_Arno[['Water Volume', 'Temperature', 'Rainfall']])
plt.show()
sns.pairplot(Water_Spring_Amiata[['Water Volume', 'Temperature', 'Rainfall']])
plt.show()
sns.pairplot(Water_Spring_Lupa[['Water Volume', 'Temperature', 'Rainfall']])
plt.show()
sns.pairplot(Water_Spring_Madonna_di_Canneto[['Water Volume', 'Temperature', 'Rainfall']])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Pair Plots for Feature Relationships
# ----> 2 sns.pairplot(aquifer_auser[['Water Volume', 'Temperature', 'Rainfall']])
#       3 plt.show()
#       4 sns.pairplot(Aquifer_Doganella[['Water Volume', 'Temperature', 'Rainfall']])
#
# NameError: name 'aquifer_auser' is not defined
